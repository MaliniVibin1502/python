# %% [markdown]
# <a href="https://colab.research.google.com/github/MaliniVibin1502/pythonprojects/blob/main/Usedcarpricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a project on the dataset of used car pricing. The data is taken from Kaggle.
# Data Wrangling -  preprocessing of data by handling missing values, correcting the data format, standardise and normalise the data. Python liraries used for the project are pandas,numpy, matplotlib, seaborn and scipy.
#
# Further Analysis done on the dataset includes :
# - Analyzing-Individual-Feature-Patterns-Using-Visualization
# - Analyzing Individual Feature Patterns using Visualization
# - Descriptive-Statistical-Analysis
# - Descriptive Statistical Analysis
# - Grouping
# - Correlation and Causation
#
# Model development - the respective model will be developed to make predictions
#
# Model Evaluation and Refinement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
uc= pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data",names= headers)
uc.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# Handling missing data in the dataframe
# - Convert ? to NaN
# - Evaluating Missing data
# - Dealing with the missing data

# %%
uc.replace("?", np.nan,inplace=True)
uc.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2               NaN         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1               NaN         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0               NaN         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
missing_data=uc.isnull()
missing_data.head(10)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
# 5      False               True  False      False       False         False
# 6      False              False  False      False       False         False
# 7      False               True  False      False       False         False
# 8      False              False  False      False       False         False
# 9      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# Counting the missing values for each column

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %% [markdown]
# Replace by mean:
#
# - "normalized-losses": 41 missing data, replace them with mean
# - "stroke": 4 missing data, replace them with mean
# - "bore": 4 missing data, replace them with mean
# - "horsepower": 2 missing data, replace them with mean
# - "peak-rpm": 2 missing data, replace them with mean
#
#
# Replace by frequency: "num-of-doors": 2 missing data, replace them with "four".
#
#
# Drop the whole row: "price": 4 missing data, simply delete the whole row

# %%
mean_normalized_losses = uc['normalized-losses'].astype(float).mean(axis=0)
print("Mean of Normalized Losses is = ", mean_normalized_losses)
# Out:
# Mean of Normalized Losses is =  122.0

# %%
uc["normalized-losses"].replace(np.nan, mean_normalized_losses, inplace=True)
uc["normalized-losses"].isnull().value_counts()
# Out:
# False    205
# Name: normalized-losses, dtype: int64

# %%
avg_bore=uc['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3297512437810943

# %%
uc['bore'].replace(np.nan,avg_bore,inplace=True)
uc['bore'].isnull().value_counts()
# Out:
# False    205
# Name: bore, dtype: int64

# %%
avg_stroke=uc['stroke'].astype('float').mean(axis=0)
print("Average of bore:", avg_stroke)
# Out:
# Average of bore: 3.255422885572139

# %%
uc['stroke'].replace(np.nan,avg_stroke,inplace=True)
uc['stroke'].isnull().value_counts()
# Out:
# False    205
# Name: stroke, dtype: int64

# %%
avg_horsepower=uc['horsepower'].astype('float').mean(axis=0)
print("Average of bore:", avg_horsepower)
# Out:
# Average of bore: 104.25615763546799

# %%
uc['horsepower'].replace(np.nan,avg_horsepower,inplace=True)
uc['horsepower'].isnull().value_counts()
# Out:
# False    205
# Name: horsepower, dtype: int64

# %%
avg_rpm=uc['peak-rpm'].astype('float').mean(axis=0)
print("Average of bore:", avg_rpm)
# Out:
# Average of bore: 5125.369458128079

# %%
uc['peak-rpm'].replace(np.nan,avg_horsepower,inplace=True)
uc['peak-rpm'].isnull().value_counts()
# Out:
# False    205
# Name: peak-rpm, dtype: int64

# %%
uc['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
uc['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
uc["num-of-doors"].replace(np.nan, "four", inplace=True)

# %%
uc.dropna(subset=["price"], axis=0, inplace=True)
uc.reset_index(drop=True, inplace=True)

# %%
uc.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2             122.0         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1             122.0         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          2               192          bmw       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# Check and correct the data types of the data in the dataset

# %%
uc.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
uc[["bore", "stroke"]] = uc[["bore", "stroke"]].astype("float")
uc[["normalized-losses"]] = uc[["normalized-losses"]].astype("int")
uc[["price"]] = uc[["price"]].astype("float")
uc[["peak-rpm"]] = uc[["peak-rpm"]].astype("float")

# %%
uc.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# Standardising data - Convert mpg to L/100km by mathematical operation (235 divided by mpg)

# %%
uc['highway-L/100km'] = 235/uc['highway-mpg']
uc.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %% [markdown]
# Data Normalization
#
# Scale the columns "length", "width" and "height"  from 0 to 1

# %%
uc['length'] = uc['length']/uc['length'].max()
uc['width'] = uc['width']/uc['width'].max()
uc['height'] = uc['height']/uc['height'].max()

# %%
uc[['length','width','height']]
# Out:
#        length     width    height
# 0    0.811148  0.890278  0.816054
# 1    0.811148  0.890278  0.816054
# 2    0.822681  0.909722  0.876254
# 3    0.848630  0.919444  0.908027
# 4    0.848630  0.922222  0.908027
# ..        ...       ...       ...
# 196  0.907256  0.956944  0.928094
# 197  0.907256  0.955556  0.928094
# 198  0.907256  0.956944  0.928094
# 199  0.907256  0.956944  0.928094
# 200  0.907256  0.956944  0.928094
#
# [201 rows x 3 columns]

# %% [markdown]
# Binning the values into categories for analysis
#
# In the data set, "horsepower" is a real valued variable ranging from 48 to 288 and it has 59 unique values. The further analysis is done for price difference between cars with high horsepower, medium horsepower, and little horsepower (3 types)? Therefore the data horeppwer will be rearranged into three ‘bins' to simplify analysis.

# %%
uc["horsepower"]=uc["horsepower"].astype(int, copy=True)
plt.hist(uc["horsepower"])
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("Horsepower bins")
# Out:
# Text(0.5, 1.0, 'Horsepower bins')

# %%
bins = np.linspace(min(uc["horsepower"]), max(uc["horsepower"]), 4)
group_names = ['Low', 'Medium', 'High']

# %%
uc['horsepower-binned'] = pd.cut(uc['horsepower'], bins, labels=group_names, include_lowest=True )
uc[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# 15         182            Medium
# 16         182            Medium
# 17          48               Low
# 18          70               Low
# 19          70               Low

# %%
uc["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
plt.bar(group_names, uc["horsepower-binned"].value_counts())
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("Horsepower bins")
# Out:
# Text(0.5, 1.0, 'Horsepower bins')

# %%
plt.hist(uc["horsepower"], bins = 3)
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("Horsepower bins")
# Out:
# Text(0.5, 1.0, 'Horsepower bins')

# %% [markdown]
# Specifying the indicator variables for the column fuel-type and aspiration which can be used for futher analysis

# %%
uc.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'highway-L/100km', 'horsepower-binned'],
#       dtype='object')

# %%
uc['fuel-type'].value_counts()
# Out:
# gas       181
# diesel     20
# Name: fuel-type, dtype: int64

# %%
dummy_variable_1 = pd.get_dummies(uc["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
uc=pd.concat([uc,dummy_variable_1],axis=1)

# %%
uc.drop("fuel-type", axis = 1, inplace=True)

# %%
uc.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %%
uc.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'highway-L/100km', 'horsepower-binned', 'fuel-type-diesel',
#        'fuel-type-gas'],
#       dtype='object')

# %%
uc['aspiration'].value_counts()
# Out:
# std      165
# turbo     36
# Name: aspiration, dtype: int64

# %%
dummy_variable_2=pd.get_dummies(uc['aspiration'])
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variable_2.rename(columns={'std':'aspiration_std', 'turbo':'aspiration_turbo'}, inplace=True)

# %%
dummy_variable_2.head()
# Out:
#    aspiration_std  aspiration_turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0

# %%
uc=pd.concat([uc,dummy_variable_2],axis=1)

# %%
uc.drop('aspiration',axis=1,inplace=True)

# %%
uc.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  peak-rpm  \
# 0          rwd           front        88.6  0.811148  0.890278  ...    5000.0
# 1          rwd           front        88.6  0.811148  0.890278  ...    5000.0
# 2          rwd           front        94.5  0.822681  0.909722  ...    5000.0
# 3          fwd           front        99.8  0.848630  0.919444  ...    5500.0
# 4          4wd           front        99.4  0.848630  0.922222  ...    5500.0
#
# ...

# %% [markdown]
# Analysis of the data
#
#
# ---

# %%
print(uc.dtypes)
# Out:
# symboling               int64
# normalized-losses       int64
# make                   object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower              int64
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# highway-L/100km       float64
# horsepower-binned    category
# fuel-type-diesel        uint8
# fuel-type-gas           uint8
# aspiration_std          uint8
# aspiration_turbo        uint8
# dtype: object

# %%
uc.corr()
# Out:
# <ipython-input-227-dc6047754ba7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   uc.corr()
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# ...

# %%
sp_corr=uc[['bore','stroke','compression-ratio','horsepower']].corr()
sp_corr
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566903
# stroke            -0.055390  1.000000           0.187871    0.098128
# compression-ratio  0.001263  0.187871           1.000000   -0.214489
# horsepower         0.566903  0.098128          -0.214489    1.000000

# %% [markdown]
# Linear Relationship
#
# Scatterplot of "engine-size" and "price"

# %%
sns.regplot(x="engine-size", y="price", data=uc)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %% [markdown]
# scatterplot of "highway-mpg" and "price"

# %%
sns.regplot(x='highway-L/100km',y='price',data=uc)
# Out:
# <Axes: xlabel='highway-L/100km', ylabel='price'>

# %%
uc[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# Checking if "peak-rpm" is a predictor variable of "price".

# %%
sns.regplot(x="peak-rpm", y="price", data=uc)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
uc[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.037284
# price    -0.037284  1.000000

# %% [markdown]
# Analysing the relationshp of "stroke" and "price"

# %%
sns.regplot(x="stroke", y="price", data=uc)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
uc[['stroke','price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082269
# price   0.082269  1.000000

# %% [markdown]
# Analysis of categorical variables using box plots
# - body-style and price
# - engine-location and price
# - drive-wheels and price

# %%
sns.boxplot(x="body-style", y="price", data=uc)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x="engine-location", y="price", data=uc)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x="drive-wheels", y="price", data=uc)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# Grouping & Analysis

# %%
uc['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
uc_group_one = uc[['drive-wheels','body-style','price']]

# %%
uc_group_one = uc_group_one.groupby(['drive-wheels'],as_index=False).mean()
uc_group_one
# Out:
# <ipython-input-241-c0c88d87716f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   uc_group_one = uc_group_one.groupby(['drive-wheels'],as_index=False).mean()
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
uc_gptest = uc[['drive-wheels','body-style','price']]
grouped_test1 = uc_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
group_bs=uc[['body-style','price']]
group_uc=group_bs.groupby('body-style',as_index=False).mean()
group_uc
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# Drive Wheels and Body Style vs. Price

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')


row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index


ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)


ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)


plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# Correlation and Causation
#
# - Calculating the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'.
# - Calculating the Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'.
# - Calculating the Pearson Correlation Coefficient and P-value of 'highway-mpg' vs. 'price'

# %%
pearson_coef,p_value=stats.pearsonr(uc['wheel-base'],uc['price'])
print("Pearson Coefficient = ",pearson_coef,"with P value of",p_value)
# Out:
# Pearson Coefficient =  0.584641822265508 with P value of 8.076488270732885e-20

# %%
pearson_coef,p_value=stats.pearsonr(uc['horsepower'],uc['price'])
print("Pearson Coefficient = ",pearson_coef,"with P value of",p_value)
# Out:
# Pearson Coefficient =  0.8096068016571054 with P value of 6.273536270650351e-48

# %%
pearson_coef, p_value = stats.pearsonr(uc['highway-mpg'], uc['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.704692265058953  with a P-value of P =  1.749547114447557e-31

# %% [markdown]
# **Model** **Development**
# ---
#
# - Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %% [markdown]
# How could "highway-mpg" help us predict car price?
# For this example, we want to look at how highway-mpg can help

# %%
x=uc[['highway-mpg']]
y=uc['price']
lm.fit(x,y)
yhat=lm.predict(x)
yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %% [markdown]
# Calculating the slope and intercept to check if the Linear Regression model is received as Yhat=a+bX

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# Train the model using "engine-size" as the independent variable and "price" as the dependent variable

# %%
lm1=LinearRegression()
X=uc[['engine-size']]
Y=uc['price']
lm1.fit(X,Y)
Yhat=lm1.predict(X)
Yhat[0:5]
# Out:
# array([13728.4631336 , 13728.4631336 , 17399.38347881, 10224.40280408,
#        14729.62322775])

# %%
lm1.intercept_
# Out:
# -7963.338906281042

# %%
lm1.coef_
# Out:
# array([166.86001569])

# %% [markdown]
# Mutiple Linear Regression
#
# With good predictors of price are:
# - Horsepower
# - Curb-weight
# - Engine-size
# - Highway-mpg
#
# Developing model using these variables as the predictor variables to check if the multiple linear regression model is developed.
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4

# %%
lm2=LinearRegression()
X1=uc[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y1=uc['price']
lm2.fit(X1,Y1)
Yhat1=lm2.predict(X1)
Yhat1[0:5]
# Out:
# array([13699.07700462, 13699.07700462, 19052.71346719, 10620.61524404,
#        15520.90025344])

# %%
lm2.intercept_
# Out:
# -15811.863767729232

# %%
lm2.coef_
# Out:
# array([53.53022809,  4.70805253, 81.51280006, 36.1593925 ])

# %% [markdown]
# Model evaluation using Visualisations
# ---
# - Regression Plot
# - Residual Plot
# - Distribution plot

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="highway-mpg", y="price", data=uc)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
plt.figure(figsize=(10,10))
sns.regplot(x="peak-rpm", y="price", data=uc)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
uc[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.043889 -0.037284
# highway-mpg -0.043889     1.000000 -0.704692
# price       -0.037284    -0.704692  1.000000

# %%
plt.figure(figsize=(10,10))
sns.residplot(x=uc['highway-mpg'], y=uc['price'])
plt.show()

# %%
plt.figure(figsize=(10,10))
ax1 = sns.distplot(uc['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat1, hist=False, color="b", label="Fitted Values" , ax=ax1)
# Out:
# <ipython-input-265-7622b8448738>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(uc['price'], hist=False, color="r", label="Actual Value")
# <ipython-input-265-7622b8448738>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
f1 = np.polyfit(uc['highway-mpg'], uc['price'], 11)
p1 = np.poly1d(f1)
print(p1)
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()
PlotPolly(p1,uc['highway-mpg'], uc['price'], 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %% [markdown]
# Polynomial transformation on multiple features.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2,include_bias=False)

# %%
Z=uc[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
x_poly=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
x_poly.shape
# Out:
# (201, 14)

# %% [markdown]
# Pipelines
# ---

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,uc['price'])
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.93329646, 13102.93329646, 18226.43450275, 10391.09183955])

# %% [markdown]
# Calculation of
# - R^2 / R-squared
# - Mean Squared Error (MSE)
#
# for Simple Linear Regression, Multiple Linear Regression and Polynomial regression

# %%
#highway_mpg_fit
lm.fit(x, y)
# Find the R^2
print('The R-square is: ', lm.score(x, y))
# Out:
# The R-square is:  0.4965911884339176

# %%
yhat=lm.predict(x)
print('The output of the first four predicted value is: ', yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(uc['price'], yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639888

# %%
lm.fit(X, uc['price'])
# Find the R^2
print('The R-square is: ', lm.score(X, uc['price']))
# Out:
# The R-square is:  0.7609686443622008

# %%
y_predict=lm.predict(X)
mse=mean_squared_error(uc['price'], y_predict)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  15021126.025174143

# %%
from sklearn.metrics import r2_score

# %%
x = uc['highway-mpg']
y = uc['price']
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %%
mean_squared_error(uc['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# - Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR)
#
#
# MSE: The MSE of SLR is 3.16x10^7 while MLR has an MSE of 1.2 x10^7. The MSE of MLR is much smaller.
# R-squared: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR ~0.497 is very small compared to the R-squared for the MLR ~0.809.
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.
#
# - Simple Linear Model (SLR) vs. Polynomial Fit
# MSE: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.
# R-squared: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.
# Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting "price" with "highway-mpg" as a predictor variable.
#
# - Multiple Linear Regression (MLR) vs. Polynomial Fit
# MSE: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.
# R-squared: The R-squared for the MLR is also much larger than for the Polynomial Fit.
#
#
# Conclusion
# Comparing these three models, it is concluded that the MLR model is the best model to be able to predict price from our dataset. This result makes sense since we have 27 variables in total and we know that more than one of those variables are potential predictors of the final car price.

# %% [markdown]
# Model Evaluation and Refinement
# ----------------------------

# %% [markdown]
# Defining two functions for plotting distribution plots and polynomial plots

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.show()
    plt.close()

# %%
def PollyPlots(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))


    #training data
    #testing data
    # lr:  linear regression object
    #poly_transform:  polynomial transformation object

    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %% [markdown]
# Training and Testing the dataset for the model. We use the train and test function from scikit learn

# %%
y_data=uc['price']
x_data=uc.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 21
# number of training samples: 180

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)
print("number of test samples :", x_test1.shape[0])
print("number of training samples:",x_train1.shape[0])
# Out:
# number of test samples : 81
# number of training samples: 120

# %%
lre=LinearRegression()

# %%
lre.fit(x_train[['horsepower']], y_train)
# Out:
# LinearRegression()

# %%
lre.score(x_test[['horsepower']], y_test)
# Out:
# 0.3635480624962413

# %%
lre.score(x_train[['horsepower']], y_train)
# Out:
# 0.662028747521533

# %%
lre_forty=LinearRegression()

# %%
lre_forty.fit(x_train1[['horsepower']],y_train1)
# Out:
# LinearRegression()

# %%
lre_forty.score(x_test1[['horsepower']],y_test1)
# Out:
# 0.7139737368233016

# %%
lre_forty.score(x_train1[['horsepower']],y_train1)
# Out:
# 0.5754853866574969

# %%
from sklearn.model_selection import cross_val_score

# %%
Rcross = cross_val_score(lre, x_data[['horsepower']], y_data, cv=4)
Rcross
# Out:
# array([0.77465419, 0.51718424, 0.74814454, 0.04825398])

# %%
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.5220592359225414 and the standard deviation is 0.29130480666118436

# %%
-1 * cross_val_score(lre,x_data[['horsepower']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20251357.7835463 , 43743920.05390439, 12525158.34507633,
#        17564549.69976653])

# %%
Rc=cross_val_score(lre,x_data[['horsepower']], y_data,cv=2)
Rc.mean()
# Out:
# 0.516835099979672

# %%
from sklearn.model_selection import cross_val_predict

# %%
yhat = cross_val_predict(lre,x_data[['horsepower']], y_data,cv=4)
yhat[0:5]
# Out:
# array([14142.23793549, 14142.23793549, 20815.3029844 , 12745.549902  ,
#        14762.9881726 ])

# %% [markdown]
# Overfitting, Underfitting and Model Selection
# ---

# %%
lr=LinearRegression()
lr.fit(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']],y_train)
# Out:
# LinearRegression()

# %%
yhat_train = lr.predict(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_train[0:5]
# Out:
# array([ 7426.34910902, 28324.42490838, 14212.74872339,  4052.80810192,
#        34499.8541269 ])

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %%
yhat_test=lr.predict(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_test[0:5]
# Out:
# array([11349.68099115,  5884.25292475, 11208.31007475,  6641.03017109,
#        15565.98722248])

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %% [markdown]
# Comparing Figure 1 and Figure 2, it is evident that the distribution of the test data in Figure 1 is much better at fitting the data. This difference in Figure 2 is apparent in the range of 5000 to 15,000. This is where the shape of the distribution is extremely different.

# %% [markdown]
# Creating a degree 5 polynomial model.

# %%
pr=PolynomialFeatures(degree=5,include_bias=False)

# %% [markdown]
# Using 55 percent of the data for training and the rest for testing:

# %%
y_data=uc['price']
x_data=uc.drop('price',axis=1)

# %%
x_data
# Out:
#      symboling  normalized-losses         make num-of-doors   body-style  \
# 0            3                122  alfa-romero          two  convertible
# 1            3                122  alfa-romero          two  convertible
# 2            1                122  alfa-romero          two    hatchback
# 3            2                164         audi         four        sedan
# 4            2                164         audi         four        sedan
# ..         ...                ...          ...          ...          ...
# 196         -1                 95        volvo         four        sedan
# 197         -1                 95        volvo         four        sedan
# 198         -1                 95        volvo         four        sedan
# 199         -1                 95        volvo         four        sedan
# 200         -1                 95        volvo         four        sedan
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# ...

# %%
y_data
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, Length: 201, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)
print("Entries in training set:",x_train.shape[0],"Entreies in test set:",x_test.shape[0])
# Out:
# Entries in training set: 110 Entreies in test set: 91

# %%
x_test
# Out:
#      symboling  normalized-losses         make num-of-doors body-style  \
# 18           1                 98    chevrolet          two  hatchback
# 170         -1                 65       toyota         four      sedan
# 107          0                122       peugot         four      wagon
# 98           0                128       nissan         four      sedan
# 177         -1                122       toyota         four      wagon
# ..         ...                ...          ...          ...        ...
# 2            1                122  alfa-romero          two  hatchback
# 59           0                115        mazda         four      sedan
# 136          2                 83       subaru          two  hatchback
# 198         -1                 95        volvo         four      sedan
# 43           2                122        isuzu          two  hatchback
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# ...

# %%
x_train_pr = pr.fit_transform(x_train[['horsepower']])

# %%
x_test
# Out:
#      symboling  normalized-losses         make num-of-doors body-style  \
# 18           1                 98    chevrolet          two  hatchback
# 170         -1                 65       toyota         four      sedan
# 107          0                122       peugot         four      wagon
# 98           0                128       nissan         four      sedan
# 177         -1                122       toyota         four      wagon
# ..         ...                ...          ...          ...        ...
# 2            1                122  alfa-romero          two  hatchback
# 59           0                115        mazda         four      sedan
# 136          2                 83       subaru          two  hatchback
# 198         -1                 95        volvo         four      sedan
# 43           2                122        isuzu          two  hatchback
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# ...

# %%
x_test_pr = pr.fit_transform(x_test[['horsepower']])

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression()

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [14142.23793549 14142.23793549 20815.3029844  12745.549902  ]
# True values: [ 6295. 10698. 13860. 13499.]

# %%
PollyPlots(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly,pr)

# %% [markdown]
# R^2 of the train and test data
# ---

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.5568527854151784

# %%
poly.score(x_test_pr, y_test)
# Out:
# -29.81546817349699

# %% [markdown]
# It is seen R^2 for the training data is 0.5567 while the R^2 on the test data was -29.87. The lower the R^2, the worse the model. A negative R^2 is a sign of overfitting.

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)

    x_train_pr = pr.fit_transform(x_train[['horsepower']])

    x_test_pr = pr.fit_transform(x_test[['horsepower']])

    lr.fit(x_train_pr, y_train)

    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %% [markdown]
# Taking the polynomial regression again

# %%
pr1=PolynomialFeatures()

# %%
x_train_pr1=pr1.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])

x_test_pr1=pr1.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])

# %%
x_train_pr1.shape
# Out:
# (110, 15)

# %%
poly1=LinearRegression().fit(x_train_pr1,y_train)

# %%
yhat_test1=poly1.predict(x_test_pr1)

Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'

DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)

# %% [markdown]
# The predicted value is higher than actual value for cars where the price 10,000 range, conversely the predicted price is lower than the price cost in the 30,000 to 40,000 range. As such the model is not as accurate in these ranges.

# %% [markdown]
# Ridge Regression
# ---

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])
x_test_pr=pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])

# %%
from sklearn.linear_model import Ridge

# %%
RigeModel=Ridge(alpha=1)

# %%
RigeModel.fit(x_train_pr, y_train)
# Out:
# Ridge(alpha=1)

# %%
yhat = RigeModel.predict(x_test_pr)

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [ 6572.19586866  9634.40697746 20948.17104272 19403.38016094]
# test set : [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# Selecting the value of alpha that minimizes the test error. Creating a loop and progress bar to see how many iterations completed so far.

# %%
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha)
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)

    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|██████████| 1000/1000 [00:04<00:00, 202.11it/s, Test Score=0.564, Train Score=0.859]

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(Alpha,Rsqu_test, label='validation data  ')
plt.plot(Alpha,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# Grid Search
# ---

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %%
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
Grid1.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %%
BestRR.score(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_test)
# Out:
# 0.8411781387793232

# %%
parameters2 = [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

Grid2 = GridSearchCV(Ridge(), parameters2, cv=4)
Grid2.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
best_alpha = Grid2.best_params_['alpha']
best_ridge_model = Ridge(alpha=best_alpha)
best_ridge_model.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
# Out:
# Ridge(alpha=10000)
